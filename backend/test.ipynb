# %%
from fastapi import FastAPI
app = FastAPI()

@app.get("/")
def read_root():
   return {"Hello": "World"}

@app.get("/items/{item_id}")
def read_item(item_id: int, q: str = None):
   return {"item_id": item_id, "q": q}

# %%
import os
from geopy.geocoders import Nominatim

# %%
def hols_to_df():
    hol_path = "./hols/"
    festival_df = pd.DataFrame(columns=["Year","Month","Date","Festival_name","Country_name"])
    for file_name in os.listdir(hol_path):
        if ".hol" not in file_name:
            continue
        with open(hol_path+file_name, 'r', encoding='utf-16') as file:
            data = file.read()

        festival_datas = data.split("\n")

        # festival_datas[0] = [AUHQ_2023節日假期表] 21
        country_name = festival_datas[0].split("_")[0].split("[")[1]

        for data in festival_datas[1:]:
            # data = '開國紀念日(放假),2023/1/1'
            festival_name = data.split(",")[0]
            time = data.split(",")[1]

            year = time.split("/")[0]
            month = time.split("/")[1]
            date = time.split("/")[2]

            festival_df.loc[len(festival_df)] = [year, month, date, festival_name, country_name]
    
    return festival_df

festival_df = hols_to_df()

# %%
festival_df
# Out:
#     Year Month Date     Festival_name Country_name
# 0   2023     1    1            元旦(放假)         AUCN
# 1   2023     1    2            元旦(放假)         AUCN
# 2   2023     1   21          农历除夕(放假)         AUCN
# 3   2023     1   22         春节年初一(放假)         AUCN
# 4   2023     1   23         春节年初二(放假)         AUCN
# 5   2023     1   24         春节年初三(放假)         AUCN
# 6   2023     1   25         春节年初四(放假)         AUCN
# 7   2023     1   26         春节年初五(放假)         AUCN
# 8   2023     1   27         春节年初六(放假)         AUCN
# 9   2023     1   28            春节(补班)         AUCN
# 10  2023     1   29            春节(补班)         AUCN
# 11  2023     4    5           清明节(放假)         AUCN
# 12  2023     4   23           劳动节(补班)         AUCN
# 13  2023     4   29           劳动节(放假)         AUCN
# 14  2023     4   30           劳动节(放假)         AUCN
# 15  2023     5    1           劳动节(放假)         AUCN
# 16  2023     5    2           劳动节(放假)         AUCN
# ...

# %%
latitude, longitude = 121,43

# %%
certifi.where()
# Out:
# 'c:\\users\\benbllee\\appdata\\local\\programs\\python\\python38\\lib\\site-packages\\certifi\\cacert.pem'

# %%
import certifi
import ssl
import geopy.geocoders
from geopy.geocoders import Nominatim
ctx = ssl.create_default_context("./TMGCert.crt")
geopy.geocoders.options.default_ssl_context = ctx

geolocator = Nominatim(user_agent="geoapiExercises", scheme='http', proxies={"http":"http://benbllee:Aa0937454850*@auhqproxy.cdn.corpnet.auo.com:8080"})

def get_location_by_address(address):
    """
    透過地址獲取詳細的經緯度數據
    """
    location = geolocator.geocode(address)
    return (location.latitude, location.longitude)

address = "台北火車站"
print(get_location_by_address(address))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12212\1633360771.py in <cell line: 5>()
#       3 import geopy.geocoders
#       4 from geopy.geocoders import Nominatim
# ----> 5 ctx = ssl.create_default_context("./TMGCert.crt")
#       6 geopy.geocoders.options.default_ssl_context = ctx
#       7
#
# c:\users\benbllee\appdata\local\programs\python\python38\lib\ssl.py in create_default_context(purpose, cafile, capath, cadata)
#     730     """
#     731     if not isinstance(purpose, _ASN1Object):
# --> 732         raise TypeError(purpose)
#     733
#     734     # SSLContext sets OP_NO_SSLv2, OP_NO_SSLv3, OP_NO_COMPRESSION,
#
# TypeError: ./TMGCert.crt

# %%
import ssl

# %%
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut

def getLocation(name):
    geolocator = Nominatim(scheme='http')
    try:
        location = geolocator.geocode(name, timeout=5)
        return location
    except GeocoderTimedOut as e:
        print("Error: geocode failed on input %s with message %s" % (e.msg))

# %%
getLocation("geoapiExercises")
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12212\839985330.py in <cell line: 1>()
# ----> 1 getLocation("geoapiExercises")
#
# ~\AppData\Local\Temp\ipykernel_12212\698564037.py in getLocation(name)
#       3
#       4 def getLocation(name):
# ----> 5     geolocator = Nominatim(scheme='http')
#       6     try:
#       7         location = geolocator.geocode(name, timeout=5)
#
# c:\users\benbllee\appdata\local\programs\python\python38\lib\site-packages\geopy\geocoders\nominatim.py in __init__(self, timeout, proxies, domain, scheme, user_agent, ssl_context, adapter_factory)
#     103         if (self.domain == _DEFAULT_NOMINATIM_DOMAIN
#     104                 and self.headers['User-Agent'] in _REJECTED_USER_AGENTS):
# --> 105             raise ConfigurationError(
# ...

# %%
pip install certifi
# Out:
# Looking in indexes: http://autcbdpypi.corpnet.auo.com/simple
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
Type "help", "copyright", "credits" or "license" for more information.
>>> import certifi
>>> certifi.where()
'/usr/local/lib/python3.5/site-packages/certifi/cacert.pem'
>>> exit()
[root@localhost tmp]# cat ~/cert.pem >> /usr/local/lib/python3.5/site-packages/certifi/cacert.pem
(please specify your own .pem file location)
# Out:
#   File "C:\Users\BenBLLee\AppData\Local\Temp\ipykernel_12212\3413287474.py", line 1
#     Type "help", "copyright", "credits" or "license" for more information.
#          ^
# SyntaxError: invalid syntax

# %%
import certifi

# %%
import requests
url = 'https://nominatim.org/search?q=Newyork'
req = requests.get(url,verify=False)
# Out:
# c:\users\benbllee\appdata\local\programs\python\python38\lib\site-packages\urllib3\connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host 'auhqproxy.cdn.corpnet.auo.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
req
# Out:
# <Response [404]>

# %%
auo_account = "benbllee"
auo_password = "Aa0937454850*"
proxy = "auhqproxy.cdn.corpnet.auo.com:8080"
headers = {'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux i686; rv:64.0) Gecko/20100101 Firefox/64.0'}

# %%
import requests

url = 'https://nominatim.openstreetmap.org/search'
params = {'q': '台灣新竹市', 'format': 'json'}

response = requests.get(url, params=params)

response_json = response.json()

if response_json:
    print(f"台北车站的坐标是：({response_json[0]['lat']}, {response_json[0]['lon']})")
else:
    print("未找到台北车站的坐标")
# Out:
# 台北车站的坐标是：(24.8066333, 120.9686833)

# %%
response_json
# Out:
# [{'place_id': 308247190,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'relation',
#   'osm_id': 2849488,
#   'lat': '24.8066333',
#   'lon': '120.9686833',
#   'class': 'boundary',
#   'type': 'administrative',
#   'place_rank': 8,
#   'importance': 0.5275298488004013,
#   'addresstype': 'city',
#   'name': '新竹市',
#   'display_name': '新竹市, 臺灣',
#   'boundingbox': ['24.7125730', '24.8532113', '120.8794247', '121.0335407']}]

# %%
import urllib.request

url = 'https://nominatim.org/search?q=Newyork'

req = urllib.request.Request(url, headers=headers)

# set proxy
proxy_support = urllib.request.ProxyHandler(
        {
            'http':f'http://{auo_account}:{auo_password}@{proxy}', 
            'https':f'https://{auo_account}:{auo_password}@{proxy}',
        })

opener = urllib.request.build_opener(proxy_support)
urllib.request.install_opener(opener)
response = urllib.request.urlopen(req, timeout=2)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12212\733455419.py in <cell line: 16>()
#      14 opener = urllib.request.build_opener(proxy_support)
#      15 urllib.request.install_opener(opener)
# ---> 16 response = urllib.request.urlopen(req, timeout=2)
#
# c:\users\benbllee\appdata\local\programs\python\python38\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# c:\users\benbllee\appdata\local\programs\python\python38\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# ...

# %%
html = response.read().decode('utf-8')
html

# %%
import geopy
from geopy.geocoders import Nominatim
import requests

# 建立一個新的 requests session
s = requests.Session()

# 設定證書路徑
s.verify =  "C:\\Users\\BenBLLee\\Desktop\\世界行事曆\\backend\\TMGCert.crt"

# 設定 session 給 geopy 使用
geopy.geocoders.options.default_session = s

# 使用 geopy
geolocator = Nominatim(user_agent="myGeocoder", timeout=10)
location = geolocator.geocode("Taipei Main Station")
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# c:\users\benbllee\appdata\local\programs\python\python38\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     666             if is_new_proxy_conn:
# --> 667                 self._prepare_proxy(conn)
#     668
#
# c:\users\benbllee\appdata\local\programs\python\python38\lib\site-packages\urllib3\connectionpool.py in _prepare_proxy(self, conn)
#     931         conn.set_tunnel(self._proxy_host, self.port, self.proxy_headers)
# --> 932         conn.connect()
#     933
#
# c:\users\benbllee\appdata\local\programs\python\python38\lib\site-packages\urllib3\connection.py in connect(self)
#     361
# --> 362         self.sock = ssl_wrap_socket(
#     363             sock=conn,
#
# ...
